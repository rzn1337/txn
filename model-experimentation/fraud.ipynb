# %%
from feast import FeatureStore
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from feast import FeatureStore, AuthConfig
#
# ImportError: cannot import name 'AuthConfig' from 'feast' (/home/ali/airflow/.venv/lib/python3.12/site-packages/feast/__init__.py)

# %%
fs = FeatureStore(repo_path="../feast/fraud/feature_repo")
# Out:
# /home/ali/airflow/.venv/lib/python3.12/site-packages/feast/repo_config.py:268: DeprecationWarning: The serialization version 2 and below will be deprecated in the next release. Specifying `entity_key_serialization_version` to 3 is recommended.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 fs = FeatureStore(repo_path="../feast/fraud/feature_repo")
#
# File ~/airflow/.venv/lib/python3.12/site-packages/feast/feature_store.py:169, in FeatureStore.__init__(self, repo_path, config, fs_yaml_file)
#     165     self._registry = RemoteRegistry(
#     166         registry_config, self.config.project, None, self.config.auth_config
#     167     )
#     168 else:
# --> 169     self._registry = Registry(
#     170         self.config.project,
#     171         registry_config,
#     172         repo_path=self.repo_path,
# ...
